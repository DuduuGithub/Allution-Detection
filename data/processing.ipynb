# %% [markdown]
# 1、处理典故范围重叠
#
# “㸌如羿射九日落，矫如群帝骖龙翔。” [4, 5, 6,射日弓（后羿）]; [2, 3, 4, 5,射日弓（后羿）]  -> [2, 3, 4, 5, 6,射日弓（后羿）]

# %%
import pandas as pd
import ast
import numpy as np

# %%
def merge_connected_spans(spans_str):
    try:
        spans = ast.literal_eval(spans_str)
    except:
        return spans_str
    
    if not spans:
        return spans
    
    # 将spans按起始位置排序
    spans.sort(key=lambda x: x[0])
    
    merged_spans = []
    current_positions = None
    
    for span in spans:
        if not isinstance(span, list) or len(span) < 2:
            continue
            
        # 获取当前span的所有位置
        current_span = list(range(span[0], span[-1] + 1))
        
        if current_positions is None:
            # 第一个span
            current_positions = current_span
            continue
            
        # 检查是否与当前positions相连
        if span[0] <= current_positions[-1] + 1:
            # 相连，合并
            # 使用集合去重，然后转回有序列表
            current_positions = sorted(list(set(current_positions + current_span)))
        else:
            # 不相连，保存当前positions并开始新的span
            merged_spans.append(current_positions)
            current_positions = current_span
    
    # 添加最后一组positions
    if current_positions:
        merged_spans.append(current_positions)
    
    return merged_spans

# 读取CSV文件
df = pd.read_csv('爬取的典故数据_部分手工补全后.csv', sep='\t')

# 处理allusion_index列
df['allusion_index'] = df['allusion_index'].apply(merge_connected_spans)

# 保存处理后的数据
df.to_csv('1_process_connected_spans_data.csv', sep='\t', index=False)

# 打印一些示例进行验证
print("处理后的一些示例：")
for i, row in df.iterrows():
    if isinstance(row['allusion_index'], list) and len(row['allusion_index']) > 1:
        print(f"原句：{row['sentence']}")
        print(f"典故：{row['allusion']}")
        print(f"处理后的spans：{row['allusion_index']}")
        print("-" * 50)

# 测试代码
test_cases = [
    "[[1, 2], [4, 5]]",  # 不相连的spans
    "[[1, 2], [4, 5, 6], [5, 6, 7]]",  # 部分相连的spans
    "[[1, 2], [2, 3], [3, 4]]",  # 全部相连的spans
]

print("测试结果：")
for test in test_cases:
    result = merge_connected_spans(test)
    print(f"输入: {test}")
    print(f"输出: {result}")
    print("-" * 50)
# Out:
# 处理后的一些示例：
# 原句：僻居谋道不谋身，避病桃源不避秦。
# 典故：桃源（陶潜）
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：何用深求避秦客，吾家便是武陵源。
# 典故：桃源（陶潜）
# 处理后的spans：[[4, 5, 6], [12, 13, 14]]
# --------------------------------------------------
# 原句：悔学秦人南避地，武陵原上又徵师。
# 典故：桃源（陶潜）
# 处理后的spans：[[2, 3, 4, 5], [8, 9]]
# --------------------------------------------------
# 原句：行尽绿潭潭转幽，疑是武陵春碧流。秦人鸡犬桃花里，将比通塘渠见羞。
# 典故：桃源（陶潜）
# 处理后的spans：[[10, 11, 12], [16, 17, 18, 19]]
# --------------------------------------------------
# 原句：薜带何辞楚，桃源堪避秦。
# 典故：桃源（陶潜）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：见说桃源洞，如今犹避秦。
# 典故：桃源（陶潜）
# 处理后的spans：[[2, 3], [9, 10]]
# --------------------------------------------------
# 原句：同作危时避秦客，此行何似武陵滩。
# 典故：桃源（陶潜）
# 处理后的spans：[[4, 5, 6], [12, 13]]
# --------------------------------------------------
# 原句：青野雾销凝晋洞，碧山烟散避秦溪。已是大仙怜后进，不应来向武陵迷。
# 典故：桃源（陶潜）
# 处理后的spans：[[12, 13, 14], [28, 29]]
# --------------------------------------------------
# 原句：闻说花源堪避秦，幽寻数月不逢人。
# 典故：桃源（陶潜）
# 处理后的spans：[[2, 3], [5, 6]]
# --------------------------------------------------
# 原句：莫学武陵人，暂游桃源里。
# 典故：桃源（陶潜）
# 处理后的spans：[[2, 3, 4], [8, 9]]
# --------------------------------------------------
# 原句：秦客何年驻，仙源此地深。
# 典故：桃源（陶潜）
# 处理后的spans：[[0, 1], [6, 7]]
# --------------------------------------------------
# 原句：秦客何年驻，仙源此地深。
# 典故：桃源（陶潜）
# 处理后的spans：[[0, 1], [6, 7]]
# --------------------------------------------------
# 原句：鄙哉楚襄王，独好阳云台。
# 典故：阳台（宋玉，楚襄王，瑶姬）
# 处理后的spans：[[2, 3, 4], [8, 9, 10]]
# --------------------------------------------------
# 原句：神魂倘遇巫娥伴，犹逐朝云暮雨归。
# 典故：阳台（宋玉，楚襄王，瑶姬）
# 处理后的spans：[[4, 5], [10, 11, 12, 13]]
# --------------------------------------------------
# 原句：殷勤好取襄王意，莫向阳台梦使君。
# 典故：阳台（宋玉，楚襄王，瑶姬）
# 处理后的spans：[[4, 5, 6], [10, 11, 12]]
# --------------------------------------------------
# 原句：非关宋玉有微辞，却是襄王梦觉迟。一自高唐赋成后，楚天云雨尽堪疑。
# 典故：阳台（宋玉，楚襄王，瑶姬）
# 处理后的spans：[[10, 11, 12], [18, 19, 20]]
# --------------------------------------------------
# 原句：可惜凌波步罗袜，美人美人兮归去来，莫作朝云暮雨兮飞阳台。
# 典故：阳台（宋玉，楚襄王，瑶姬）
# 处理后的spans：[[19, 20, 21, 22], [25, 26]]
# --------------------------------------------------
# 原句：愿托襄王云雨梦，阳台今夜降神仙。
# 典故：阳台（宋玉，楚襄王，瑶姬）
# 处理后的spans：[[2, 3, 4, 5, 6], [8, 9]]
# --------------------------------------------------
# 原句：江南弄，巫山连楚梦，行雨行云几相送。
# 典故：阳台（宋玉，楚襄王，瑶姬）
# 处理后的spans：[[7, 8], [10, 11, 12, 13]]
# --------------------------------------------------
# 原句：好笑襄王大迂阔，曾卧巫云见神女。银锁金簧不得听，空劳翠辇冲泥雨。
# 典故：阳台（宋玉，楚襄王，瑶姬）
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：处士不生巫峡梦，虚劳神女下阳台。
# 典故：阳台（宋玉，楚襄王，瑶姬）
# 处理后的spans：[[4, 5, 6], [10, 11], [13, 14]]
# --------------------------------------------------
# 原句：巫山巫峡高何已，行雨行云一时起。一时起，三春暮，若言来，且就阳台路。
# 典故：阳台（宋玉，楚襄王，瑶姬）
# 处理后的spans：[[8, 9, 10, 11], [30, 31]]
# --------------------------------------------------
# 原句：萧郎不顾凤楼人，云涩回车泪脸新。
# 典故：吹箫（弄玉，秦穆公，萧史）
# 处理后的spans：[[0, 1], [4, 5]]
# --------------------------------------------------
# 原句：无复秦楼上，吹箫下凤皇。
# 典故：吹箫（弄玉，秦穆公，萧史）
# 处理后的spans：[[2, 3], [6, 7]]
# --------------------------------------------------
# 原句：不逢秦女在，何处听吹箫。
# 典故：吹箫（弄玉，秦穆公，萧史）
# 处理后的spans：[[2, 3], [9, 10]]
# --------------------------------------------------
# 原句：昔来唯有秦王女，独自吹箫乘白云。
# 典故：吹箫（弄玉，秦穆公，萧史）
# 处理后的spans：[[4, 5, 6], [10, 11]]
# --------------------------------------------------
# 原句：凤凰楼上伴吹箫，鹦鹉杯中醉留客。
# 典故：吹箫（弄玉，秦穆公，萧史）
# 处理后的spans：[[0, 1, 2], [5, 6]]
# --------------------------------------------------
# 原句：不似秦楼上，吹箫空学仙。
# 典故：吹箫（弄玉，秦穆公，萧史）
# 处理后的spans：[[2, 3], [6, 7]]
# --------------------------------------------------
# 原句：日暮吹箫杨柳陌，路人遥指凤凰楼。
# 典故：吹箫（弄玉，秦穆公，萧史）
# 处理后的spans：[[2, 3], [12, 13, 14]]
# --------------------------------------------------
# 原句：遂有冯夷来击鼓，始知嬴女善吹箫。
# 典故：吹箫（弄玉，秦穆公，萧史）
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：婉彼嬴氏女，吹箫偶萧史。
# 典故：吹箫（弄玉，秦穆公，萧史）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：弄玉已归萧史去，碧楼红树倚斜阳。
# 典故：吹箫（弄玉，秦穆公，萧史）
# 处理后的spans：[[0, 1], [4, 5]]
# --------------------------------------------------
# 原句：弄玉已归萧史去，碧楼红树倚斜阳。
# 典故：吹箫（弄玉，秦穆公，萧史）
# 处理后的spans：[[0, 1], [4, 5]]
# --------------------------------------------------
# 原句：粉面仙郎选圣朝，偶逢秦女学吹箫。
# 典故：吹箫（弄玉，秦穆公，萧史）
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：或云欲学吹凤笙，所慕灵妃媲萧史。
# 典故：吹箫（弄玉，秦穆公，萧史）
# 处理后的spans：[[5, 6], [13, 14]]
# --------------------------------------------------
# 原句：吹箫不是神仙曲，争引秦娥下凤台。
# 典故：吹箫（弄玉，秦穆公，萧史）
# 处理后的spans：[[0, 1], [10, 11], [13, 14]]
# --------------------------------------------------
# 原句：圣代留昆玉，那令愧郤诜。
# 典故：桂枝（郤诜）
# 处理后的spans：[[3, 4], [9, 10]]
# --------------------------------------------------
# 原句：之荆且愿依刘表，折桂终惭见郤诜。
# 典故：桂枝（郤诜）
# 处理后的spans：[[8, 9], [13, 14]]
# --------------------------------------------------
# 原句：之荆且愿依刘表，折桂终惭见郤诜。
# 典故：桂枝（郤诜）
# 处理后的spans：[[8, 9], [13, 14]]
# --------------------------------------------------
# 原句：大有好笑事，略陈三五个。巴歌唱者多，白雪无人和。
# 典故：白雪（宋玉）
# 处理后的spans：[[12, 13], [18, 19]]
# --------------------------------------------------
# 原句：曲高弥寡和，主善代为师。
# 典故：白雪（宋玉）
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：陶诗只采黄金实，郢曲新传白雪英。
# 典故：白雪（宋玉）
# 处理后的spans：[[8, 9], [12, 13]]
# --------------------------------------------------
# 原句：郢客吟白雪，遗向飞青天。徒劳歌此曲，举世为谁传。
# 典故：白雪（宋玉）
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：燕歌落胡雁，郢曲回阳春。
# 典故：白雪（宋玉）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：晋君听琴枉清角，巴人谁肯和阳春。
# 典故：白雪（宋玉）
# 处理后的spans：[[8, 9], [13, 14]]
# --------------------------------------------------
# 原句：吟君白雪唱，惭愧巴人肠。
# 典故：白雪（宋玉）
# 处理后的spans：[[2, 3, 4], [8, 9]]
# --------------------------------------------------
# 原句：掷笔落郢曲，巴人不能酬。
# 典故：白雪（宋玉）
# 处理后的spans：[[3, 4], [6, 7]]
# --------------------------------------------------
# 原句：巴歌掩白雪，鲍肆埋兰芳。
# 典故：白雪（宋玉）
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：唱高知和寡，小子斐然狂。
# 典故：白雪（宋玉）
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：兴逸何妨寻剡客，唱高还肯寄巴人。
# 典故：白雪（宋玉）
# 处理后的spans：[[8, 9], [13, 14]]
# --------------------------------------------------
# 原句：懦夫仰高节，下里继阳春。
# 典故：白雪（宋玉）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：千年郢曲后，复此闻阳春。
# 典故：白雪（宋玉）
# 处理后的spans：[[2, 3], [9, 10]]
# --------------------------------------------------
# 原句：华筵重处宗盟地，白雪飞时郢曲春。
# 典故：白雪（宋玉）
# 处理后的spans：[[8, 9], [12, 13]]
# --------------------------------------------------
# 原句：今日谢庭飞白雪，巴歌不复旧阳春。
# 典故：白雪（宋玉）
# 处理后的spans：[[5, 6], [8, 9], [13, 14]]
# --------------------------------------------------
# 原句：铮鏦闻郢唱，次第发巴音。
# 典故：白雪（宋玉）
# 处理后的spans：[[3, 4], [9, 10]]
# --------------------------------------------------
# 原句：郢唱转高谁敢和，巴歌相顾自销声。
# 典故：白雪（宋玉）
# 处理后的spans：[[0, 1], [8, 9]]
# --------------------------------------------------
# 原句：蓬莱径是曾到来，方丈岂唯方一丈。
# 典故：蓬莱
# 处理后的spans：[[0, 1], [8, 9]]
# --------------------------------------------------
# 原句：三山浮海倚蓬瀛，路入真元险尽平。
# 典故：蓬莱
# 处理后的spans：[[0, 1], [5, 6]]
# --------------------------------------------------
# 原句：何必三山待鸾鹤，年年此地是瀛洲。
# 典故：蓬莱
# 处理后的spans：[[2, 3], [13, 14]]
# --------------------------------------------------
# 原句：许随黄绮辈，閒唱紫芝歌。
# 典故：紫芝（刘邦，夏黄公，东园公，甪里先生，绮里季，四皓）
# 处理后的spans：[[2, 3], [8, 9, 10]]
# --------------------------------------------------
# 原句：借问商山贤四皓，不知此后更何如。
# 典故：紫芝（刘邦，夏黄公，东园公，甪里先生，绮里季，四皓）
# 处理后的spans：[[2, 3], [5, 6]]
# --------------------------------------------------
# 原句：遥羡商山翁，闲歌紫芝秀。
# 典故：紫芝（刘邦，夏黄公，东园公，甪里先生，绮里季，四皓）
# 处理后的spans：[[2, 3, 4], [7, 8, 9]]
# --------------------------------------------------
# 原句：徐生何代降坤维，曾伴园公采紫芝。
# 典故：紫芝（刘邦，夏黄公，东园公，甪里先生，绮里季，四皓）
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：黄绮更归何处去，洛阳城内有商山。
# 典故：紫芝（刘邦，夏黄公，东园公，甪里先生，绮里季，四皓）
# 处理后的spans：[[0, 1], [13, 14]]
# --------------------------------------------------
# 原句：庙前亦有商山路，不学老翁歌紫芝。
# 典故：紫芝（刘邦，夏黄公，东园公，甪里先生，绮里季，四皓）
# 处理后的spans：[[4, 5], [12, 13, 14]]
# --------------------------------------------------
# 原句：东归自是缘清兴，莫比商山咏紫芝。
# 典故：紫芝（刘邦，夏黄公，东园公，甪里先生，绮里季，四皓）
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：二曰：劝君登商山，不用觅商山皓。
# 典故：紫芝（刘邦，夏黄公，东园公，甪里先生，绮里季，四皓）
# 处理后的spans：[[6, 7], [12, 13, 14]]
# --------------------------------------------------
# 原句：谁能跼迹依三辅，会就商山访四翁。
# 典故：紫芝（刘邦，夏黄公，东园公，甪里先生，绮里季，四皓）
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：何日到彭泽，长歌陶令前。
# 典故：陶潜
# 处理后的spans：[[3, 4], [8, 9]]
# --------------------------------------------------
# 原句：靖节何须彭泽逢，菊洲松岛水悠溶。
# 典故：陶潜
# 处理后的spans：[[0, 1], [4, 5]]
# --------------------------------------------------
# 原句：闲行闲坐藉莎烟，此贤堪思二古贤。陶靖节古彭泽畔，贺知章在镜池边。
# 典故：陶潜
# 处理后的spans：[[16, 17, 18], [20, 21]]
# --------------------------------------------------
# 原句：濯缨易为水，何必泛沧浪。
# 典故：沧浪（屈原）
# 处理后的spans：[[0, 1], [9, 10]]
# --------------------------------------------------
# 原句：扣船应渔父，因唱沧浪吟。
# 典故：沧浪（屈原）
# 处理后的spans：[[3, 4], [8, 9]]
# --------------------------------------------------
# 原句：何必沧浪去，即此可濯缨。
# 典故：沧浪（屈原）
# 处理后的spans：[[2, 3], [9, 10]]
# --------------------------------------------------
# 原句：渼陂水色澄于镜，何必沧浪始濯缨。
# 典故：沧浪（屈原）
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：讵假沧浪上，将濯楚臣缨。
# 典故：沧浪（屈原）
# 处理后的spans：[[2, 3], [7, 8, 9, 10]]
# --------------------------------------------------
# 原句：啸父知机先忆鱼，季鹰无事已思鲈。
# 典故：鲈鱼（张翰）
# 处理后的spans：[[8, 9], [13, 14]]
# --------------------------------------------------
# 原句：西风张翰苦思鲈，如斯丰味能知否。
# 典故：鲈鱼（张翰）
# 处理后的spans：[[2, 3], [5, 6]]
# --------------------------------------------------
# 原句：和羹使用非胥靡，忆鲙言词小季鹰。
# 典故：鲈鱼（张翰）
# 处理后的spans：[[8, 9], [13, 14]]
# --------------------------------------------------
# 原句：西江近有鲈鱼否，张翰扁舟始到家。
# 典故：鲈鱼（张翰）
# 处理后的spans：[[4, 5], [8, 9]]
# --------------------------------------------------
# 原句：逢秋不拟同张翰，为忆鲈鱼却叹嗟。
# 典故：鲈鱼（张翰）
# 处理后的spans：[[5, 6], [9, 10, 11]]
# --------------------------------------------------
# 原句：鲈鱼斫鲙输张翰，橘树呼奴羡李衡。
# 典故：鲈鱼（张翰）
# 处理后的spans：[[0, 1], [5, 6]]
# --------------------------------------------------
# 原句：季鹰可是思鲈鲙，引退知时自古难。
# 典故：鲈鱼（张翰）
# 处理后的spans：[[0, 1], [4, 5]]
# --------------------------------------------------
# 原句：惭非蒋生径，不敢望求羊。
# 典故：三径（求仲，羊仲，蒋诩）
# 处理后的spans：[[2, 3, 4], [9, 10]]
# --------------------------------------------------
# 原句：其兄因献璞，再刖不履地。卞和名永永，与宝不相坠。劝尔出门行，行难莫行易。
# 典故：卞和
# 处理后的spans：[[3, 4], [12, 13]]
# --------------------------------------------------
# 原句：痛玉不痛身，抱璞求所归。
# 典故：卞和
# 处理后的spans：[[0, 1], [6, 7]]
# --------------------------------------------------
# 原句：却羡卞和双刖足，一生无复没阶趋。
# 典故：卞和
# 处理后的spans：[[2, 3], [5, 6]]
# --------------------------------------------------
# 原句：徒为卞和识，不遇楚王珍。
# 典故：卞和
# 处理后的spans：[[2, 3], [8, 9, 10]]
# --------------------------------------------------
# 原句：居然一片荆山玉，可怕无人是卞和。
# 典故：卞和
# 处理后的spans：[[4, 5, 6], [13, 14]]
# --------------------------------------------------
# 原句：抱玉入楚国，见疑古所闻。良宝终见弃，徒劳三献君。
# 典故：卞和
# 处理后的spans：[[0, 1], [20, 21]]
# --------------------------------------------------
# 原句：卞和试三献，期子在秋砧。
# 典故：卞和
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：莫作千年别，归来城郭新。
# 典故：令威（丁令威）
# 处理后的spans：[[2, 3, 4], [8, 9, 10]]
# --------------------------------------------------
# 原句：故园华表高高在，可得不如丁令威。
# 典故：令威（丁令威）
# 处理后的spans：[[0, 1, 2, 3], [12, 13, 14]]
# --------------------------------------------------
# 原句：斗间紫气分明后，擘地成川看化龙。
# 典故：双剑（干将，张华，莫邪，雷焕）
# 处理后的spans：[[0, 1, 2, 3], [13, 14]]
# --------------------------------------------------
# 原句：我来拟学磻溪叟，白首钓璜非陆沉。
# 典故：磻溪（吕尚，周文王）
# 处理后的spans：[[4, 5, 6], [10, 11]]
# --------------------------------------------------
# 原句：君不见朝歌屠叟辞棘津，八十西来钓渭滨。宁羞白发照清水，逢时吐气思经纶。
# 典故：磻溪（吕尚，周文王）
# 处理后的spans：[[3, 4, 5, 6], [15, 16, 17]]
# --------------------------------------------------
# 原句：太公渭川水，李斯上蔡门。钓周猎秦安黎元，小鱼㕙兔何足言。
# 典故：磻溪（吕尚，周文王）
# 处理后的spans：[[2, 3], [12, 13]]
# --------------------------------------------------
# 原句：乘兴嫌太迟，焚却子猷船。
# 典故：乘兴（戴逵，王徽之）
# 处理后的spans：[[0, 1], [8, 9, 10]]
# --------------------------------------------------
# 原句：无因见安道，兴尽愁人心。
# 典故：乘兴（戴逵，王徽之）
# 处理后的spans：[[2, 3, 4], [6, 7]]
# --------------------------------------------------
# 原句：笑杀山阴雪中客，等閒乘兴又须回。
# 典故：乘兴（戴逵，王徽之）
# 处理后的spans：[[2, 3, 4], [10, 11]]
# --------------------------------------------------
# 原句：遐想鱼鹏化，开襟九万风。
# 典故：大鹏（庄子）
# 处理后的spans：[[3, 4], [8, 9, 10]]
# --------------------------------------------------
# 原句：骥蹄初蹑景，鹏翅欲抟扶。
# 典故：大鹏（庄子）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：采薇易为山，何必登首阳。
# 典故：采薇（伯夷，叔齐）
# 处理后的spans：[[0, 1], [9, 10]]
# --------------------------------------------------
# 原句：公方伯夷操，事殷不事周。
# 典故：采薇（伯夷，叔齐）
# 处理后的spans：[[2, 3], [8, 9, 10]]
# --------------------------------------------------
# 原句：举才天道亲，首阳谁采薇。
# 典故：采薇（伯夷，叔齐）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：伯夷在首阳，欲往无轻舟。
# 典故：采薇（伯夷，叔齐）
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：首阳山翠千年在，好奠冰壶吊伯夷。
# 典故：采薇（伯夷，叔齐）
# 处理后的spans：[[0, 1], [13, 14]]
# --------------------------------------------------
# 原句：夷齐是何人，独守西山饿。
# 典故：采薇（伯夷，叔齐）
# 处理后的spans：[[0, 1], [8, 9, 10]]
# --------------------------------------------------
# 原句：立惟孤竹子，拂衣首阳山。夷齐各一身，穷饿未为难。
# 典故：采薇（伯夷，叔齐）
# 处理后的spans：[[2, 3], [8, 9], [12, 13]]
# --------------------------------------------------
# 原句：又引王子乔，吹笙舞松风。
# 典故：子晋（王子乔）
# 处理后的spans：[[2, 3, 4], [6, 7]]
# --------------------------------------------------
# 原句：忆昔王子晋，凤笙游云空。怜寿不贵色，身世两无穷。
# 典故：子晋（王子乔）
# 处理后的spans：[[2, 3, 4], [6, 7]]
# --------------------------------------------------
# 原句：且同山简醉，倒载莫褰帷。
# 典故：山简
# 处理后的spans：[[2, 3], [6, 7]]
# --------------------------------------------------
# 原句：山公醉酒时，酩酊襄阳下。
# 典故：山简
# 处理后的spans：[[0, 1, 2], [6, 7]]
# --------------------------------------------------
# 原句：斑竹年来笋自生，白苹春尽花空落。遥望零陵见旧丘，苍梧云起至今愁。唯馀帝子千行泪，添作潇湘万里流。
# 典故：湘妃（唐尧，女英，娥皇，舜，虞舜）
# 处理后的spans：[[0, 1], [34, 35]]
# --------------------------------------------------
# 原句：不见湘妃鼓瑟时，至今斑竹临江活。
# 典故：湘妃（唐尧，女英，娥皇，舜，虞舜）
# 处理后的spans：[[2, 3], [10, 11]]
# --------------------------------------------------
# 原句：翠帐云屏白玉床，啼鸟休啼花莫笑，女英新喜得娥皇。
# 典故：湘妃（唐尧，女英，娥皇，舜，虞舜）
# 处理后的spans：[[16, 17], [21, 22]]
# --------------------------------------------------
# 原句：娥皇不语启娇靥，女英目成转心惬。
# 典故：湘妃（唐尧，女英，娥皇，舜，虞舜）
# 处理后的spans：[[0, 1], [8, 9]]
# --------------------------------------------------
# 原句：此去不须求彩服，紫衣全胜老莱衣。
# 典故：老莱（老莱子）
# 处理后的spans：[[5, 6], [12, 13, 14]]
# --------------------------------------------------
# 原句：水底鲤鱼幸无数，愿君别后垂尺素。
# 典故：双鱼
# 处理后的spans：[[2, 3], [13, 14]]
# --------------------------------------------------
# 原句：尺素如残雪，结为双鲤鱼。
# 典故：双鱼
# 处理后的spans：[[0, 1], [8, 9, 10]]
# --------------------------------------------------
# 原句：汉口双鱼白锦鳞，令传尺素报情人。
# 典故：双鱼
# 处理后的spans：[[2, 3], [10, 11]]
# --------------------------------------------------
# 原句：春江足鱼雁，彼此勤尺素。
# 典故：双鱼
# 处理后的spans：[[3, 4], [9, 10]]
# --------------------------------------------------
# 原句：烹鲤无尺素，筌鱼劳寸心。
# 典故：双鱼
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：运筹初减灶，调鼎未和羹。
# 典故：盐梅（傅说，殷高宗）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：莫贪题咏兴，商鼎待盐梅。
# 典故：盐梅（傅说，殷高宗）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：季子祸从怜富贵，颜生道在乐箪瓢。
# 典故：颜子（孔子，颜回）
# 处理后的spans：[[8, 9], [12, 13, 14]]
# --------------------------------------------------
# 原句：吾徒自多感，颜子只箪瓢。
# 典故：颜子（孔子，颜回）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：国境未安身未立，至今颜巷守箪瓢。
# 典故：颜子（孔子，颜回）
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：太史侯凫影，王乔随鹤翎。
# 典故：双凫（王乔）
# 处理后的spans：[[3, 4], [6, 7]]
# --------------------------------------------------
# 原句：翔凫犹化履，狎雉尚驯童。
# 典故：双凫（王乔）
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：作京雄近县，开阁宠平津。
# 典故：平津（公孙弘，薛泽）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：平津旧东阁，深巷见南山。
# 典故：平津（公孙弘，薛泽）
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：蜀魄千年尚怨谁，声声啼血向花枝。
# 典故：蜀魄（杜宇）
# 处理后的spans：[[0, 1], [10, 11]]
# --------------------------------------------------
# 原句：杜宇冤亡积有时，年年啼血动人悲。
# 典故：蜀魄（杜宇）
# 处理后的spans：[[0, 1], [10, 11]]
# --------------------------------------------------
# 原句：于何车马日憧憧，李膺门馆争登龙。
# 典故：登龙（李膺）
# 处理后的spans：[[8, 9, 10, 11], [13, 14]]
# --------------------------------------------------
# 原句：楚玉已曾分卞玉，膺门依旧是龙门。
# 典故：登龙（李膺）
# 处理后的spans：[[8, 9], [13, 14]]
# --------------------------------------------------
# 原句：登龙不及三千士，虚度膺门二十春。
# 典故：登龙（李膺）
# 处理后的spans：[[0, 1], [10, 11]]
# --------------------------------------------------
# 原句：燕昭延郭隗，遂筑黄金台。剧辛方赵至，邹衍复齐来。
# 典故：黄金台（燕昭王，郭隗）
# 处理后的spans：[[2, 3, 4], [8, 9, 10]]
# --------------------------------------------------
# 原句：君不见昔时燕家重郭隗，拥彗折节无嫌猜。剧辛乐毅感恩分，输肝剖胆效英才。昭王白骨萦蔓草，谁人更扫黄金台。
# 典故：黄金台（燕昭王，郭隗）
# 处理后的spans：[[11, 12], [47, 48, 49]]
# --------------------------------------------------
# 原句：从兹阮籍泪，且免泣途穷。
# 典故：途穷（阮籍）
# 处理后的spans：[[2, 3, 4], [8, 9, 10]]
# --------------------------------------------------
# 原句：昔余闻姮娥，窃药驻云发。不自娇玉颜，方希炼金骨。飞去身莫返，含笑坐明月。紫宫誇蛾眉，随手会凋歇。
# 典故：嫦娥（羿，姮娥）
# 处理后的spans：[[3, 4], [6, 7]]
# --------------------------------------------------
# 原句：姮娥谩偷药，长寡老中闲。
# 典故：嫦娥（羿，姮娥）
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：梅生亦何事，来作南昌尉。
# 典故：梅福
# 处理后的spans：[[0, 1], [8, 9, 10]]
# --------------------------------------------------
# 原句：隐吏逢梅福，游山忆谢公。
# 典故：梅福
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：回瞻魏阙路，空复子牟心。
# 典故：魏阙（公子牟）
# 处理后的spans：[[2, 3], [8, 9, 10]]
# --------------------------------------------------
# 原句：谁见子牟意，悁劳书魏阙。
# 典故：魏阙（公子牟）
# 处理后的spans：[[2, 3, 4], [9, 10]]
# --------------------------------------------------
# 原句：季子黑貂敝，得无妻嫂欺。
# 典故：貂裘（秦惠王，苏秦）
# 处理后的spans：[[2, 3, 4], [8, 9, 10]]
# --------------------------------------------------
# 原句：洛浦有宓妃，飘飖雪争飞。
# 典故：洛浦（宓妃，曹植）
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：应知子建怜罗袜，顾步裴回拾翠钗。
# 典故：洛浦（宓妃，曹植）
# 处理后的spans：[[2, 3, 4, 5, 6], [12, 13]]
# --------------------------------------------------
# 原句：回雪凌波游洛浦，遇陈王。
# 典故：洛浦（宓妃，曹植）
# 处理后的spans：[[2, 3], [5, 6]]
# --------------------------------------------------
# 原句：我本楚狂人，凤歌笑孔丘。
# 典故：楚狂（孔子，楚狂）
# 处理后的spans：[[2, 3], [6, 7, 8, 9, 10]]
# --------------------------------------------------
# 原句：复值接舆醉，狂歌五柳前。
# 典故：楚狂（孔子，楚狂）
# 处理后的spans：[[2, 3, 4], [6, 7]]
# --------------------------------------------------
# 原句：狂歌欲叹凤，失路反占龟。
# 典故：楚狂（孔子，楚狂）
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：接舆亦是狂歌者，更就将军乞一声。
# 典故：楚狂（孔子，楚狂）
# 处理后的spans：[[0, 1], [4, 5]]
# --------------------------------------------------
# 原句：鲁圣虚泣鳞，楚狂浪歌凤。
# 典故：楚狂（孔子，楚狂）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：青门种瓜人，旧日东陵侯。
# 典故：邵平（召平）
# 处理后的spans：[[0, 1, 2, 3], [8, 9, 10]]
# --------------------------------------------------
# 原句：丈人文力犹强健，岂傍青门学种瓜。
# 典故：邵平（召平）
# 处理后的spans：[[9, 10, 11], [13, 14]]
# --------------------------------------------------
# 原句：看却龙髯攀不得，红霞零落鼎湖空。
# 典故：鼎湖（黄帝）
# 处理后的spans：[[2, 3], [12, 13]]
# --------------------------------------------------
# 原句：坠剑悲乔岳，号弓泣鼎湖。
# 典故：鼎湖（黄帝）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：最怆号弓处，龙髯上紫霄。
# 典故：鼎湖（黄帝）
# 处理后的spans：[[2, 3], [6, 7]]
# --------------------------------------------------
# 原句：一朝铸鼎降龙驭，小臣髯绝不得去。
# 典故：鼎湖（黄帝）
# 处理后的spans：[[2, 3], [5, 6]]
# --------------------------------------------------
# 原句：龙宫欣访旧，莺谷忝迁乔。
# 典故：迁莺
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：骊龙颔被探珠去，老蚌胚还应月生。
# 典故：骊珠
# 处理后的spans：[[0, 1, 2], [4, 5]]
# --------------------------------------------------
# 原句：凤形怜彩笔，龙颔借骊珠。
# 典故：骊珠
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：湛露飞尧酒，熏风入舜弦。
# 典故：南风（舜）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：不闻北斗倾尧酒，空觉南风入舜琴。
# 典故：南风（舜）
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：湛露晞尧日，薰风入舜弦。
# 典故：南风（舜）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：常爱宓子贱，鸣琴能自亲。邑中静无事，岂不由其身。何意千年后，寂寞无此人。
# 典故：鸣琴（宓子贱）
# 处理后的spans：[[2, 3, 4], [6, 7]]
# --------------------------------------------------
# 原句：织锦作短书，肠随回文结。
# 典故：锦字（苏若兰）
# 处理后的spans：[[0, 1], [8, 9]]
# --------------------------------------------------
# 原句：扣角干名计已疏，剑歌休恨食无鱼。
# 典故：弹铗（田文，冯谖）
# 处理后的spans：[[8, 9], [12, 13, 14]]
# --------------------------------------------------
# 原句：谁怜愁苦多衰改，未到潘年有二毛。
# 典故：二毛（潘岳）
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：孟光傥未嫁，梁鸿正须妇。
# 典故：梁鸿（孟光，梁鸿）
# 处理后的spans：[[0, 1], [6, 7]]
# --------------------------------------------------
# 原句：梁鸿不肯仕，孟光甘布裙。君虽不读书，此事耳亦闻。
# 典故：梁鸿（孟光，梁鸿）
# 处理后的spans：[[0, 1], [6, 7]]
# --------------------------------------------------
# 原句：莲府才为绿水宾，忽乘骢马入咸秦。
# 典故：莲府（庾杲之，王俭，萧缅）
# 处理后的spans：[[0, 1], [4, 5, 6]]
# --------------------------------------------------
# 原句：窈窕凤皇姝，倾城复倾国。
# 典故：倾城（刘彻，李延年）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：蔡琰没去造胡笳，苏武归来持汉节。
# 典故：苏武（刘彻，苏武）
# 处理后的spans：[[8, 9, 10], [13, 14]]
# --------------------------------------------------
# 原句：应宜仙子胡麻拌，因送刘郎与阮郎。
# 典故：阮郎（刘晨，阮肇）
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：迟尔为舟楫，相将济巨川。
# 典故：济川（傅说，殷高宗）
# 处理后的spans：[[3, 4], [8, 9, 10]]
# --------------------------------------------------
# 原句：尽将舟楫板桥去，早晚归来更济川。
# 典故：济川（傅说，殷高宗）
# 处理后的spans：[[2, 3], [13, 14]]
# --------------------------------------------------
# 原句：孙弘阁闹无閒客，傅说舟忙不借人。何似抡才济川外，别开池馆交亲。
# 典故：济川（傅说，殷高宗）
# 处理后的spans：[[8, 9, 10], [20, 21]]
# --------------------------------------------------
# 原句：愿当舟楫便，一附济川人。
# 典故：济川（傅说，殷高宗）
# 处理后的spans：[[2, 3], [8, 9]]
# --------------------------------------------------
# 原句：莫持西江水，空许东溟臣。
# 典故：涸鳞（庄子）
# 处理后的spans：[[2, 3, 4], [8, 9, 10]]
# --------------------------------------------------
# 原句：出笼穷短翮，委辙涸枯鳞。
# 典故：涸鳞（庄子）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：帝女飞衔石，鲛人卖泪绡。
# 典故：鲛人
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：镜湖女儿嫁鲛人，鲛绡逼肖也不分。
# 典故：鲛人
# 处理后的spans：[[5, 6], [8, 9]]
# --------------------------------------------------
# 原句：西施越溪女，明艳光云海。未入吴王宫殿时，浣纱古石今犹在。若到天涯思故人，浣纱石上窥明月。
# 典故：西施（夫差，范蠡，西施）
# 处理后的spans：[[0, 1], [20, 21], [36, 37, 38]]
# --------------------------------------------------
# 原句：馆娃人尽醉，西子始新妆。
# 典故：西施（夫差，范蠡，西施）
# 处理后的spans：[[0, 1], [6, 7]]
# --------------------------------------------------
# 原句：越山重叠越溪斜，西子休怜解浣纱。
# 典故：西施（夫差，范蠡，西施）
# 处理后的spans：[[8, 9], [13, 14]]
# --------------------------------------------------
# 原句：十日笙歌一宵梦，苧萝因雨失西施。
# 典故：西施（夫差，范蠡，西施）
# 处理后的spans：[[8, 9], [13, 14]]
# --------------------------------------------------
# 原句：叹凤嗟身否，伤麟怨道穷。
# 典故：获麟（孔子，鲁哀公）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：弃繻当日路，应竞看终军。
# 典故：弃繻（终军）
# 处理后的spans：[[0, 1], [9, 10]]
# --------------------------------------------------
# 原句：丰貂长组金张辈，驷马文衣许史家。
# 典故：金张（张安世，许广汉，金日磾，史高）
# 处理后的spans：[[4, 5], [12, 13, 14]]
# --------------------------------------------------
# 原句：丰貂长组金张辈，驷马文衣许史家。
# 典故：金张（张安世，许广汉，金日磾，史高）
# 处理后的spans：[[4, 5], [12, 13, 14]]
# --------------------------------------------------
# 原句：清风北窗卧，可以傲羲皇。
# 典故：傲羲皇（陶潜，伏羲氏，羲和）
# 处理后的spans：[[2, 3, 4], [8, 9, 10]]
# --------------------------------------------------
# 原句：陈遵已投辖，山公正坐池。
# 典故：投辖（陈遵）
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：借问问津者，宁知沮溺贤。
# 典故：沮溺（子路，孔子，桀溺，长沮）
# 处理后的spans：[[2, 3], [8, 9]]
# --------------------------------------------------
# 原句：借问问津者，宁知沮溺贤。
# 典故：沮溺（子路，孔子，桀溺，长沮）
# 处理后的spans：[[2, 3], [8, 9]]
# --------------------------------------------------
# 原句：山中宰相陶弘景，谷口耕夫郑子真。
# 典故：谷口（郑朴）
# 处理后的spans：[[8, 9, 10], [12, 13, 14]]
# --------------------------------------------------
# 原句：耕岩非谷口，结草即河滨。
# 典故：谷口（郑朴）
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：乘舟觅吏经舆县，为酒求官得步兵。
# 典故：步兵（阮籍）
# 处理后的spans：[[8, 9, 10, 11], [13, 14]]
# --------------------------------------------------
# 原句：玉人此日心中事，何似乘羊入市年。
# 典故：玉人（卫玠，裴楷）
# 处理后的spans：[[0, 1], [10, 11, 12, 13]]
# --------------------------------------------------
# 原句：睡时分得江淹梦，五色毫端弄逸才。
# 典故：五色笔（张协，江淹，郭璞，丘迟）
# 处理后的spans：[[4, 5, 6], [8, 9, 10]]
# --------------------------------------------------
# 原句：征南幕下带长刀，梦笔深藏五色毫。
# 典故：五色笔（张协，江淹，郭璞，丘迟）
# 处理后的spans：[[8, 9], [12, 13, 14]]
# --------------------------------------------------
# 原句：未把彩毫还郭璞，乞留残锦与丘迟。
# 典故：五色笔（张协，江淹，郭璞，丘迟）
# 处理后的spans：[[2, 3, 4, 5, 6], [10, 11]]
# --------------------------------------------------
# 原句：迁人同卫鹤，谬上懿公轩。
# 典故：乘轩（卫懿公）
# 处理后的spans：[[3, 4], [8, 9, 10]]
# --------------------------------------------------
# 原句：陈琳能草檄，含笑出长平。
# 典故：陈琳（陈琳，曹操）
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：岂令永和人，独擅山阴游。
# 典故：永和（王羲之）
# 处理后的spans：[[2, 3], [8, 9, 10]]
# --------------------------------------------------
# 原句：岂令永和人，独擅山阴游。
# 典故：永和（王羲之）
# 处理后的spans：[[2, 3], [8, 9, 10]]
# --------------------------------------------------
# 原句：请缨期系虏，枕草誓捐躯。
# 典故：长缨（终军）
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：鲈鱼正美不归去，空戴南冠学楚囚。
# 典故：南冠（钟仪）
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：罗敷昔时秦氏女，千载无人空处所。
# 典故：罗敷
# 处理后的spans：[[0, 1], [4, 5, 6]]
# --------------------------------------------------
# 原句：双旌千骑骈东陌，独有罗敷望上头。
# 典故：罗敷
# 处理后的spans：[[2, 3], [10, 11]]
# --------------------------------------------------
# 原句：尝闻庞德公，家住洞庭水。终身栖鹿门，不入襄阳市。夫君弄明月，灭景清淮里。高踪邈难追，可与古人比。
# 典故：庞公
# 处理后的spans：[[2, 3, 4], [15, 16]]
# --------------------------------------------------
# 原句：尚平方毕娶，疏广念归期。
# 典故：尚平（向长）
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：况无婚嫁累，应拍尚平肩。
# 典故：尚平（向长）
# 处理后的spans：[[2, 3, 4], [8, 9]]
# --------------------------------------------------
# 原句：鹿鸣验食野，鱼乐知观濠。
# 典故：濠梁（惠施，庄子）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：海边曾狎鸟，濠上正观鱼。
# 典故：濠梁（惠施，庄子）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：孙弘莫惜频开閤，韩信终期别筑坛。
# 典故：登坛（刘邦，萧何，韩信）
# 处理后的spans：[[8, 9], [13, 14]]
# --------------------------------------------------
# 原句：到日池塘春草绿，谢公应梦惠连来。
# 典故：池塘生春草（谢惠连，谢灵运）
# 处理后的spans：[[2, 3, 4, 5], [11, 12, 13]]
# --------------------------------------------------
# 原句：楼下当垆称卓女，楼头伴客名莫愁。
# 典故：当垆（卓文君，司马相如）
# 处理后的spans：[[2, 3], [5, 6]]
# --------------------------------------------------
# 原句：两卷素书留贳酒，一柯樵斧坐看棋。
# 典故：烂柯（王质）
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：区区精卫鸟，衔木空哀吟。
# 典故：精卫
# 处理后的spans：[[2, 3], [6, 7]]
# --------------------------------------------------
# 原句：精卫一微物，犹恐填海平。
# 典故：精卫
# 处理后的spans：[[0, 1], [8, 9]]
# --------------------------------------------------
# 原句：夷门得隐沦，而与侯生亲。
# 典故：侯嬴
# 处理后的spans：[[0, 1], [8, 9]]
# --------------------------------------------------
# 原句：傥其公子重回顾，何必侯嬴长抱关。
# 典故：侯嬴
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：应怜抱关者，贫病老夷门。
# 典故：侯嬴
# 处理后的spans：[[2, 3], [9, 10]]
# --------------------------------------------------
# 原句：季布无二诺，侯嬴重一言。
# 典故：金诺（季布，曹丘生）
# 处理后的spans：[[2, 3, 4], [8, 9, 10]]
# --------------------------------------------------
# 原句：满目飞明镜，归心折大刀。
# 典故：刀头（任立政，李陵）
# 处理后的spans：[[2, 3, 4], [8, 9, 10]]
# --------------------------------------------------
# 原句：书中自报刀头约，天上三看破镜飞。
# 典故：刀头（任立政，李陵）
# 处理后的spans：[[4, 5], [12, 13, 14]]
# --------------------------------------------------
# 原句：总使榴花能一醉，终须萱草暂忘忧。
# 典故：萱草
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：朝天御史非韩寿，莫窃香来带累人。
# 典故：韩寿（贾充，贾午，韩寿）
# 处理后的spans：[[5, 6], [9, 10]]
# --------------------------------------------------
# 原句：笑读曹娥碑，沉吟黄绢语。
# 典故：黄绢（曹操，杨修，杨脩，曹娥，曹盱）
# 处理后的spans：[[2, 3, 4], [8, 9]]
# --------------------------------------------------
# 原句：因寻黄绢字，为我吊曹盱。
# 典故：黄绢（曹操，杨修，杨脩，曹娥，曹盱）
# 处理后的spans：[[2, 3, 4], [9, 10]]
# --------------------------------------------------
# 原句：自尔厌游侠，闭户方垂帷。
# 典故：下帷（董仲舒）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：斩鳌翼娲皇，炼石补天维。
# 典故：补天（女娲）
# 处理后的spans：[[3, 4], [8, 9]]
# --------------------------------------------------
# 原句：苍水使者扪赤绦，龙伯国人罢钓鳌。
# 典故：钓鳌
# 处理后的spans：[[8, 9, 10, 11], [13, 14]]
# --------------------------------------------------
# 原句：沙丘无漂母，谁肯饭王孙。
# 典故：漂母（韩信，漂母）
# 处理后的spans：[[3, 4], [8, 9, 10]]
# --------------------------------------------------
# 原句：不意伶伦子，吹之学凤鸣。
# 典故：伶伦（伶伦，黄帝）
# 处理后的spans：[[2, 3], [8, 9, 10]]
# --------------------------------------------------
# 原句：谁言版筑士，犹处傅岩中。
# 典故：傅岩（傅说）
# 处理后的spans：[[2, 3], [8, 9]]
# --------------------------------------------------
# 原句：传闻帝乐奏钧天，傥冀微躬备五弦。
# 典故：钧天（赵简子）
# 处理后的spans：[[2, 3], [5, 6]]
# --------------------------------------------------
# 原句：娱宾歌湛露，广乐奏钧天。
# 典故：钧天（赵简子）
# 处理后的spans：[[6, 7], [9, 10]]
# --------------------------------------------------
# 原句：任子偶垂沧海钓，戴逵虚认少微星。
# 典故：任公
# 处理后的spans：[[0, 1], [4, 5, 6]]
# --------------------------------------------------
# 原句：巨灵咆哮擘两山，洪波喷箭射东海。
# 典故：巨灵
# 处理后的spans：[[0, 1], [4, 5, 6]]
# --------------------------------------------------
# 原句：叶公好尚浑疏阔，忽见真龙几丧明。
# 典故：真龙（子张，鲁哀公，沈诸梁）
# 处理后的spans：[[0, 1, 2, 3], [10, 11]]
# --------------------------------------------------
# 原句：惠我双龙不言价，等闲不敢将悬挂。恐是叶公好假龙，及见真龙却惊怕。
# 典故：真龙（子张，鲁哀公，沈诸梁）
# 处理后的spans：[[18, 19], [26, 27]]
# --------------------------------------------------
# 原句：望夫登高山，化石竟不返。
# 典故：望夫
# 处理后的spans：[[0, 1], [6, 7]]
# --------------------------------------------------
# 原句：数钱教姹女，买药问巴賨。
# 典故：姹女
# 处理后的spans：[[0, 1], [3, 4]]
# --------------------------------------------------
# 原句：不逢萧史休回首，莫见洪崖又拍肩。
# 典故：洪崖（洪崖，郭璞）
# 处理后的spans：[[10, 11], [13, 14]]
# --------------------------------------------------
# 原句：贤有不黔突，圣有不暖席。
# 典故：突不黔（墨子，孔子）
# 处理后的spans：[[3, 4], [9, 10]]
# --------------------------------------------------
# 原句：何郎独在无恩泽，不似当初傅粉时。
# 典故：何郎（何晏，曹睿）
# 处理后的spans：[[0, 1], [12, 13]]
# --------------------------------------------------
# 原句：若缀寿阳公主额，六宫争肯学梅妆。
# 典故：梅妆（寿阳公主）
# 处理后的spans：[[2, 3, 4, 5], [13, 14]]
# --------------------------------------------------
# 原句：不是守株空待兔，终当逐鹿出林丘。
# 典故：守株
# 处理后的spans：[[2, 3], [5, 6]]
# --------------------------------------------------
# 原句：尚有绨袍赠，应怜范叔寒。不知天下士，犹作布衣看。
# 典故：绨袍（范雎，须贾）
# 处理后的spans：[[2, 3, 4], [8, 9, 10]]
# --------------------------------------------------
# 原句：不能更出尘中也，百炼刚为绕指柔。
# 典故：绕指（刘琨）
# 处理后的spans：[[8, 9], [12, 13, 14]]
# --------------------------------------------------
# 原句：曾家机上闻投杼，尹氏园中见掇蜂。
# 典故：投杼（曾参）
# 处理后的spans：[[0, 1, 2], [5, 6]]
# --------------------------------------------------
# 原句：拊心却笑西子颦，掩鼻谁忧郑姬谤。
# 典故：掩鼻（郑袖）
# 处理后的spans：[[8, 9], [12, 13, 14]]
# --------------------------------------------------
# 测试结果：
# 输入: [[1, 2], [4, 5]]
# 输出: [[1, 2], [4, 5]]
# --------------------------------------------------
# 输入: [[1, 2], [4, 5, 6], [5, 6, 7]]
# 输出: [[1, 2], [4, 5, 6, 7]]
# --------------------------------------------------
# 输入: [[1, 2], [2, 3], [3, 4]]
# 输出: [[1, 2, 3, 4]]
# --------------------------------------------------

# %% [markdown]
# 2、处理未在提供的异形词范围内的情况

# %%
import difflib
import csv

# %%
# 加载数据
final_data = pd.read_csv('process_connected_spans_data.csv', sep='\t')  # 诗句和典故的原数据
variation_data = pd.read_csv('典故的异形数据.csv', sep='\t')  # 典故的异形数据

# 使用difflib计算最长公共子串
def longest_common_substring(str1, str2):
    sequence_matcher = difflib.SequenceMatcher(None, str1, str2)
    match = sequence_matcher.find_longest_match(0, len(str1), 0, len(str2))
    return str1[match.a: match.a + match.size]

# 创建一个新DataFrame用于存放修改过的行
modified_rows = []
no_match_rows = []  # 新增：存储没有匹配的行

# 遍历final_data中的每一行
for idx, row in final_data.iterrows():
    if row['variation_number'] == 0:
        sentence = row['sentence']
        allusions = row['allusion'].split(';')  # 拆分多个典故
        
        allusion_index = []  # 存储多个典故的匹配位置
        matched_allusions = 0  # 记录匹配成功的典故数

        for allusion in allusions:
            variation_list = variation_data[variation_data['allusion'] == allusion]['variation_list'].values
            
            if len(variation_list) > 0:
                variation_list = eval(variation_list[0])  # 将字符串类型的variation_list转换成列表
                merged_variations = ''.join(variation_list)  # 合并所有变体为一个长字符串
                
                # 查找最长公共子串
                longest_match = longest_common_substring(merged_variations, sentence)
                
                if longest_match:
                    # 更新变体列表，添加新的异形典故
                    if longest_match not in variation_list:
                        variation_list.append(longest_match)

                    # 更新variation_data
                    variation_data.at[variation_data[variation_data['allusion'] == allusion].index[0], 'variation_list'] = str(variation_list)
                    
                    # 记录匹配位置
                    match_start = sentence.find(longest_match)
                    match_end = match_start + len(longest_match)
                    allusion_index.append([match_start, match_end])  # 记录该典故的匹配位置

                    matched_allusions += 1  # 匹配成功的典故数加1

        if matched_allusions > 0:
            final_data.at[idx, 'variation_number'] = matched_allusions  # 更新variation_number为匹配的典故数
            final_data.at[idx, 'allusion_index'] = str(allusion_index)  # 保存多个典故的匹配位置

            # 保存修改后的行
            modified_rows.append(final_data.loc[idx])
        else:
            no_match_rows.append(final_data.loc[idx])  # 如果没有找到匹配的典故，记录此行

# 将修改过的行保存到新的DataFrame
modified_data = pd.DataFrame(modified_rows)

# 将没有匹配的行保存到新的DataFrame
no_match_data = pd.DataFrame(no_match_rows)

# 保存到新的CSV文件
final_data.to_csv('2_processed_data.csv', index=False, sep='\t')
variation_data.to_csv('updated_典故的异性数据.csv', index=False, sep='\t',quoting=csv.QUOTE_ALL)
modified_data.to_csv('modified_rows.csv', index=False, sep='\t')  # 保存修改过的行
no_match_data.to_csv('no_match_rows.csv', index=False, sep='\t')  # 保存没有匹配的行

# %% [markdown]
# 3.1、位置识别数据集的处理：同诗句不同典故合并

# %%
data = pd.read_csv("processed_data.csv",sep = "	")

result = data.groupby('sentence').agg({
    'author': 'first',  # 保留第一条作者
    'title': 'first',   # 保留第一条标题
    'allusion': lambda x: ';'.join(x),  # 合并典故，以分号分隔
    'variation_number': 'sum',  # 求和典故变体数
    'allusion_index': lambda x: ';'.join(x)  # 合并索引，逗号分隔后再用分号分隔不同典故
}).reset_index()

def transform_allusion_index(row):
    # 拆分 allusion 和 allusion_index
    allusions = row['allusion'].split(';')
    allusion_indices = row['allusion_index'].split(';')
    
    # 组合为目标格式
    combined = []
    for allusion, indices in zip(allusions, allusion_indices):
        index_list = indices.strip('[]')  # 去掉索引的外部括号
        combined.append(f"[{index_list},{allusion}]")  # 按目标格式拼接

    return ';'.join(combined)

# 对 DataFrame 的每一行应用函数
result['transformed_allusion'] = result.apply(transform_allusion_index, axis=1)

def adjust_transformed_allusion(row):
    # 获取 transformed_allusion 的值
    transformed_allusion = row['transformed_allusion']
    allusions = row['allusion'].split(';')  # 获取所有典故名列表
    
    # 初始化变量
    adjusted = transformed_allusion
    current_allusion_index = 0  # 当前典故的索引
    
    # 遍历 transformed_allusion 并找到 ] 后的 ,
    i = 0
    while i < len(adjusted):
        if adjusted[i] == ']' and i + 1 < len(adjusted) and adjusted[i + 1] == ',':
            # 在 ] 前插入当前典故名
            current_allusion = allusions[current_allusion_index]
            adjusted = adjusted[:i] + f',{current_allusion}' + adjusted[i:]
            i += len(current_allusion) + 1  # 跳过插入的典故名长度
            
            # 如果当前典故名已经完全应用，切换到下一个典故
            current_allusion_index = min(current_allusion_index + 1, len(allusions) - 1)
        
        i += 1
    
    return adjusted

# 对 DataFrame 的每一行应用函数
result['transformed_allusion'] = result.apply(adjust_transformed_allusion, axis=1)


def replace_comma_after_bracket(row):
    return row['transformed_allusion'].replace('],', '];')

# 对 `transformed_allusion` 列应用替换函数
result['transformed_allusion'] = result.apply(replace_comma_after_bracket, axis=1)

result.to_csv('3_1_merged_data.csv', sep='\t', index=False, encoding='utf-8')

# %% [markdown]
# 3.2 类型识别数据集的处理：针对type的数据分布平衡器

# %%
import numpy as np
from collections import Counter
from torch.utils.data import WeightedRandomSampler
from tqdm import tqdm

# %%
def balance_dataset(input_file, output_file, min_threshold=15, max_ratio=0.35):
    """
    平衡数据集，只对样本数特别少的典故进行补充
    Args:
        input_file: 输入文件路径
        output_file: 输出文件路径
        min_threshold: 最小样本数阈值，低于此值的典故将被平衡
        max_ratio: 最大样本数与平均样本数的比率阈值
    """
    print(f"读取数据文件: {input_file}")
    df = pd.read_csv(input_file, sep='\t')
    
    # 统计原始典故分布
    allusion_counts = Counter(df['allusion'].dropna())
    
    # 计算平均样本数和标准差
    mean_count = np.mean(list(allusion_counts.values()))
    target_count = int(mean_count * (1 + max_ratio))  # 设置目标样本数
    
    print("\n数据统计:")
    print(f"典故总数: {len(allusion_counts)}")
    print(f"平均样本数: {mean_count:.2f}")
    print(f"目标样本数: {target_count}")
    print(f"最小样本数阈值: {min_threshold}")
    
    print("\n原始典故分布:")
    for allusion, count in allusion_counts.most_common():
        print(f"{allusion}: {count}条")
    
    # 准备平衡后的数据
    balanced_data = []
    
    # 对每个典故进行平衡
    for allusion, count in tqdm(allusion_counts.items(), desc="平衡数据"):
        # 获取当前典故的所有样本
        allusion_samples = df[df['allusion'] == allusion]
        balanced_data.append(allusion_samples)  # 保留原始数据
        
        # 只对样本数过少的典故进行平衡
        if count < min_threshold:
            # 计算需要补充的样本数
            target = min(target_count, max(min_threshold, int(mean_count * 0.7)))
            samples_needed = target - count
            
            if samples_needed > 0:
                # 采样补充
                sampled = allusion_samples.sample(n=samples_needed, replace=True)
                balanced_data.append(sampled)
    
    # 合并所有采样数据
    balanced_df = pd.concat(balanced_data, ignore_index=True)
    
    
    # 打印平衡后的统计信息
    print("\n平衡后的典故分布:")
    balanced_counts = Counter(balanced_df['allusion'].dropna())
    for allusion, count in balanced_counts.most_common():
        print(f"{allusion}: {count}条")
    
    # 计算平衡后的统计指标
    balanced_mean = np.mean(list(balanced_counts.values()))
    balanced_std = np.std(list(balanced_counts.values()))
    print(f"\n平衡后统计:")
    print(f"平均样本数: {balanced_mean:.2f}")
    print(f"标准差: {balanced_std:.2f}")
    print(f"原始数据集大小: {len(df)}")
    print(f"平衡后数据集大小: {len(balanced_df)}")
    
    # 保存平衡后的数据集
    balanced_df.to_csv(output_file, sep='\t', index=False)
    print(f"\n平衡后的数据集已保存至: {output_file}")

if __name__ == "__main__":
    input_file = "2_processed_data.csv"
    output_file = "3_2_balanced_data.csv"
    balance_dataset(input_file, output_file)
# Out:
# 读取数据文件: 2_processed_data.csv
#
# 数据统计:
# 典故总数: 1013
# 平均样本数: 14.78
# 目标样本数: 19
# 最小样本数阈值: 15
#
# 原始典故分布:
# 桃源（陶潜）: 170条
# 阳台（宋玉，楚襄王，瑶姬）: 169条
# 吹箫（弄玉，秦穆公，萧史）: 130条
# 桂枝（郤诜）: 127条
# 白雪（宋玉）: 121条
# 蓬莱: 120条
# 紫芝（刘邦，夏黄公，东园公，甪里先生，绮里季，四皓）: 103条
# 谢朓: 91条
# 陶潜: 88条
# 沧浪（屈原）: 88条
# 鲈鱼（张翰）: 78条
# 三径（求仲，羊仲，蒋诩）: 77条
# 卞和: 76条
# 令威（丁令威）: 75条
# 双剑（干将，张华，莫邪，雷焕）: 69条
# 磻溪（吕尚，周文王）: 68条
# 乘兴（戴逵，王徽之）: 68条
# 骢马（桓典）: 68条
# 五马: 64条
# 大鹏（庄子）: 64条
# 相如（司马相如）: 63条
# 采薇（伯夷，叔齐）: 63条
# 子晋（王子乔）: 62条
# 长沙谪（贾谊）: 61条
# 凤池（荀勖）: 60条
# 山简: 59条
# 乘槎: 58条
# 湘妃（唐尧，女英，娥皇，舜，虞舜）: 57条
# 老莱（老莱子）: 56条
# 谢公（谢安）: 54条
# 五柳（陶潜）: 53条
# 贾谊: 52条
# 解榻（周璆，徐稚，陈蕃）: 51条
# 双鱼: 50条
# 盐梅（傅说，殷高宗）: 50条
# 颜子（孔子，颜回）: 49条
# 支公（支道林）: 47条
# 绝弦（伯牙，钟子期）: 47条
# 甘棠（召公姬奭）: 46条
# 竹林期（刘伶，向秀，子咸，山涛，嵇康，王咸，王戎，阮咸，阮籍）: 46条
# 白鸥（列子）: 46条
# 麟阁（丙吉，刘德，刘洵，张安世，杜延年，梁丘贺，萧望之，苏武，赵充国，霍光，韩增，魏相）: 46条
# 壶中（壶公）: 46条
# 绣衣: 45条
# 双凫（王乔）: 45条
# 柳营（周亚夫，徐厉）: 44条
# 平津（公孙弘，薛泽）: 44条
# 桑田（麻姑）: 44条
# 蜀魄（杜宇）: 43条
# 沧洲: 43条
# 登龙（李膺）: 43条
# 五湖心（范蠡，勾践）: 43条
# 严陵（严光）: 43条
# 冯唐: 43条
# 蝴蝶（庄子）: 42条
# 黄金台（燕昭王，郭隗）: 42条
# 青鸟（刘彻，西王母）: 42条
# 柏台: 42条
# 鸳鹭: 40条
# 勒燕然（窦宪）: 40条
# 漉酒（陶潜）: 17条
# 西方社（慧远，宗炳）: 17条
# 画眉（张敞）: 17条
# 蓬山: 17条
# 宣室: 17条
# 棣萼: 17条
# 借寇（寇恂）: 17条
# 解网（汤）: 17条
# 无全牛（庖丁）: 17条
# 还珠（孟尝）: 17条
# 雀罗（翟公）: 17条
# 金掌（汉武帝）: 17条
# 登坛（刘邦，萧何，韩信）: 17条
# 池塘生春草（谢惠连，谢灵运）: 17条
# 中圣（徐邈）: 17条
# 葛洪（葛洪，葛玄）: 17条
# 当垆（卓文君，司马相如）: 17条
# 白社: 16条
# 连城（秦昭王，蔺相如）: 16条
# 瑶台: 16条
# 卧袁安（袁安）: 16条
# 烂柯（王质）: 16条
# 知音: 16条
# 吊屈（贾谊，屈原）: 16条
# 泛梗（苏秦）: 16条
# 龙竹（费长房）: 16条
# 著鞭（祖逖）: 16条
# 披云（乐广，卫瓘）: 16条
# 依刘（王粲，刘表）: 16条
# 洪炉: 16条
# 精卫: 16条
# 祢衡: 16条
# 玉山颓（嵇康）: 16条
# 黄绶: 16条
# 客星（严光）: 16条
# 独醒（屈原）: 16条
# 麋鹿群（伯夷）: 16条
# 梁园（刘武）: 16条
# 临池（张芝）: 16条
# 云中鸡犬（刘安）: 15条
# 五丁: 15条
# 骏骨（燕昭王，郭隗）: 15条
# 焦尾（蔡邕）: 15条
# 击壤（尧，舜）: 15条
# 石渠: 15条
# 金马客（东方朔）: 15条
# 青蝇: 15条
# 移文（周颙，孔稚圭）: 15条
# 安期（安期生）: 15条
# 石桥（秦始皇）: 15条
# 分阃: 15条
# 倚天剑: 15条
# 侯嬴: 15条
# 趋庭（孔子，孔鲤，陈亢）: 15条
# 木奴（孙休，李衡）: 15条
# 白眉（马良）: 15条
# 陵谷: 15条
# 祢衡挝（孔融，曹操，祢衡）: 15条
# 玉京: 15条
# 甑生尘（范冉）: 15条
# 渥洼种: 15条
# 金诺（季布，曹丘生）: 15条
# 风驭（列禦寇）: 15条
# 梁苑客（刘武，司马相如，邹阳，枚乘）: 15条
# 文姬（蔡琰，蔡邕，曹操）: 15条
# 金兰: 15条
# 桃叶（桃叶，王子敬，王献之）: 14条
# 缩地（费长房）: 14条
# 骅骝: 14条
# 石崇: 14条
# 刀头（任立政，李陵）: 14条
# 劫灰（刘彻）: 14条
# 日车（羲和）: 14条
# 过隙: 14条
# 月桂: 14条
# 大隐: 14条
# 蟾: 14条
# 六印（苏秦）: 14条
# 倒屣（王粲，蔡邕）: 14条
# 书空（殷浩）: 14条
# 遏云（秦青，薛谭）: 14条
# 傅野（傅说，武丁）: 14条
# 阮籍: 14条
# 长安日（司马昭）: 14条
# 刘伶（刘伶）: 14条
# 萧曹: 14条
# 北海尊（孔融）: 14条
# 谏猎（扬雄）: 14条
# 萱草: 14条
# 梁尘（虞公）: 14条
# 韩寿（贾充，贾午，韩寿）: 14条
# 贾生泪（贾谊）: 14条
# 六龙: 14条
# 逐鹿（蒯通）: 13条
# 鹤氅: 13条
# 千日醉（刘玄石）: 13条
# 盐车（汗明，伯乐）: 13条
# 曳裾（邹阳）: 13条
# 买赋（刘彻，司马相如，陈皇后）: 13条
# 陶令醉（陶潜）: 13条
# 河源（张骞）: 13条
# 为霖（傅说，殷高宗）: 13条
# 天骄: 13条
# 偷桃（东方朔）: 13条
# 飞锡: 13条
# 公干（刘桢）: 13条
# 鸡黍（张劭，范式）: 13条
# 凤诏（石虎）: 13条
# 褰帷: 13条
# 方朔（东方朔）: 13条
# 西园（曹丕）: 13条
# 羊公（羊祜）: 13条
# 斩楼兰（刘彻）: 13条
# 暗投（邹阳）: 13条
# 右军（王羲之）: 13条
# 梁甫（诸葛亮）: 13条
# 隐侯（沈约，鲍照）: 13条
# 箫韶: 13条
# 鼓瑟（女英，娥皇，舜）: 13条
# 姹女: 13条
# 明妃（王昭君）: 12条
# 南浦（江淹）: 12条
# 黄绢（曹操，杨修，杨脩，曹娥，曹盱）: 12条
# 八骏（周穆王，西王母）: 12条
# 骑省（潘岳）: 12条
# 邓林（夸父）: 12条
# 鹦鹉赋: 12条
# 衔环（杨宝）: 12条
# 蒲轮（刘彻）: 12条
# 闲居赋（潘岳）: 12条
# 黄屋: 12条
# 子房（张良）: 12条
# 大王风（宋玉，楚王）: 12条
# 木雁（庄子）: 12条
# 下帷（董仲舒）: 12条
# 李将军（李广，卫青）: 12条
# 弦惊（魏加）: 12条
# 楚材: 12条
# 齐竽（南郭先生）: 12条
# 文园: 12条
# 前席（贾谊）: 12条
# 拥鼻（谢安）: 12条
# 三顾（刘备，诸葛亮）: 12条
# 天马（刘彻）: 12条
# 从军乐（王粲）: 12条
# 贪泉（吴隐之）: 12条
# 伯乐: 12条
# 补天（女娲）: 12条
# 倚玉（夏侯玄，曹睿，毛曾）: 12条
# 抽簪: 12条
# 冲天（楚庄王，淳于髡，齐威王）: 12条
# 方寸: 12条
# 东床（王羲之）: 12条
# 伯道无儿（邓攸）: 12条
# 宴镐（周武王）: 12条
# 桑榆: 12条
# 瓮间卧（毕卓）: 12条
# 五车（惠施，庄子）: 11条
# 三独（宣秉）: 11条
# 直如弦: 11条
# 此君（王徽之）: 11条
# 潜夫（王符）: 11条
# 纵横: 11条
# 下车（武王）: 11条
# 日边（司马昭）: 11条
# 铁冠: 11条
# 佩刀（吕虔，王祥，王览）: 11条
# 黄霸: 11条
# 伍员涛（伍员，文种）: 11条
# 萧寺（萧子云，萧衍）: 11条
# 栖梧: 11条
# 张骞: 11条
# 三岁字: 11条
# 孟母邻（孟子，孟母）: 11条
# 钓鳌: 11条
# 陆机: 11条
# 埋轮（侯文，张纲）: 11条
# 月窟: 11条
# 买山（支遁，深公，巢父，许由）: 11条
# 归去来（陶潜）: 11条
# 颍川政（黄霸）: 11条
# 扫门（魏勃）: 11条
# 嵇康懒（山涛，嵇康）: 11条
# 佳气（刘秀，苏伯阿）: 11条
# 漂母（韩信，漂母）: 11条
# 金微: 11条
# 元瑜（阮瑀）: 11条
# 傲吏: 11条
# 三千客（田文，魏无忌，黄歇）: 11条
# 薜荔衣: 11条
# 粉署: 9条
# 华亭（陆云，陆机）: 9条
# 廉颇: 8条
# 三杰（张良，萧何，韩信）: 8条
# 何水部（何逊）: 8条
# 何逊: 8条
# 建安作: 8条
# 锦帐: 8条
# 金丸（韩嫣）: 8条
# 淮南药（刘安）: 8条
# 熊轼: 8条
# 李膺: 8条
# 广成子: 8条
# 望夫: 8条
# 金埒（王济）: 8条
# 九转: 8条
# 杏田（董奉）: 8条
# 虎溪（陶潜，僧慧远）: 8条
# 九皋: 8条
# 黄公（王戎）: 8条
# 三黜（柳下惠）: 8条
# 公车: 8条
# 绛帐（马融）: 8条
# 系日: 8条
# 和鸣（懿氏，陈完）: 8条
# 乘桴（孔子）: 8条
# 牧羊儿（黄初平）: 8条
# 折槛（张禹，朱云）: 8条
# 触藩: 8条
# 天吴: 8条
# 三缄（孔子）: 8条
# 燕石: 8条
# 麋鹿姑苏（伍员，刘安）: 8条
# 适荆蛮（王粲）: 8条
# 夫子墙（子贡，孔子）: 8条
# 素餐: 8条
# 射雕手（斛律光）: 8条
# 忘筌: 8条
# 苍梧: 8条
# 貂蝉: 8条
# 却秦（鲁仲连）: 8条
# 腐鼠（庄子）: 8条
# 紫泥: 8条
# 洪崖（洪崖，郭璞）: 8条
# 王粲诗（王粲）: 8条
# 郑驿（郑当时）: 8条
# 漳滨卧（刘桢）: 8条
# 白头吟: 8条
# 姑射: 8条
# 应刘（刘桢，应玚）: 8条
# 一瓢（许由）: 8条
# 冶长非罪（公冶长）: 8条
# 杯渡: 8条
# 瑶华: 8条
# 燕赵女: 8条
# 悬弧: 8条
# 吊鹤（陶侃之母湛氏）: 8条
# 韩康: 8条
# 突不黔（墨子，孔子）: 8条
# 郗超（王珣，郗超）: 8条
# 雕虫: 8条
# 鹑服: 8条
# 负郭（苏秦）: 8条
# 鸣岐: 8条
# 何郎（何晏，曹睿）: 8条
# 薏苡谤（马援）: 8条
# 铜柱（马援）: 8条
# 镊白（左思，齐高帝）: 8条
# 诸生（叔孙通）: 8条
# 潘兴（潘岳）: 8条
# 卧辙（侯霸，秦彭）: 8条
# 负鼎（伊尹）: 8条
# 平子赋（张衡）: 8条
# 题凤（吕安，嵇喜，嵇康）: 8条
# 贰师: 8条
# 蜗舍: 8条
# 式微: 8条
# 公主嫁乌孙（刘建，刘细君，乌孙昆莫）: 8条
# 青衿: 8条
# 旰食（伍奢）: 8条
# 梅妆（寿阳公主）: 8条
# 柳恽: 8条
# 起予（卜商，孔子）: 8条
# 灵和柳（张绪）: 8条
# 履声（郑崇）: 8条
# 庾公（庾亮）: 7条
# 玄度: 7条
# 士龙（荀隐，陆云）: 7条
# 铃阁: 7条
# 埙篪: 7条
# 刘桢病（刘桢）: 7条
# 周郎: 7条
# 荐祢（孔融，邹阳，祢衡）: 7条
# 一戎: 7条
# 曾参: 7条
# 许由: 7条
# 前筹（张良）: 7条
# 竹马: 7条
# 青囊: 7条
# 洗兵: 7条
# 鹿鸣: 7条
# 王陵戆（刘邦，王陵）: 7条
# 少君: 7条
# 曳尾（庄子）: 5条
# 句芒: 5条
# 焚稿（羊祜，谢弘微）: 5条
# 孝廉船（刘惔，司马昱，张凭）: 5条
# 阮家贫（阮咸，阮籍）: 5条
# 鹢路: 5条
# 盗泉: 5条
# 覆车: 5条
# 倒戟（赵盾，灵辄）: 5条
# 弹随: 5条
# 三休: 5条
# 少微堕（谢敷）: 5条
# 大堤: 5条
# 翠华: 5条
# 沈约瘦（徐勉，沈约）: 5条
# 沈郎钱: 5条
# 十洲: 5条
# 江充: 5条
# 赐环: 5条
# 叔度（黄宪）: 5条
# 丝纶: 5条
# 鹔鹴换酒（卓文君，司马相如）: 5条
# 孙楚: 5条
# 刘琨啸（刘琨）: 5条
# 周南太史公（司马谈，司马迁）: 5条
# 唐生（唐举）: 5条
# 马融笛（马融）: 5条
# 满籯金（韦贤）: 5条
# 青毡（王徽之，王操之，王献之）: 5条
# 天籁: 5条
# 池上杯（司马炎，束皙）: 5条
# 章甫: 5条
# 荣启期: 5条
# 地仙: 5条
# 东郭履（东郭先生）: 5条
# 秋胡（秋胡妻）: 5条
# 燕霜（邹衍）: 5条
# 卧牛衣（王章）: 5条
# 放鹤（支遁）: 5条
# 彭殇（彭祖）: 5条
# 犯龙鳞: 5条
# 返魂香: 5条
# 学稼（孔子，樊迟）: 5条
# 累安邑（闵贡）: 5条
# 隔银河（牵牛，织女）: 5条
# 暴泥: 5条
# 骑白鹿（卫叔卿）: 5条
# 二陆（陆机，陆云，陆弟）: 5条
# 虞翻骨相屯（虞翻）: 5条
# 鄂君（鄂皙）: 5条
# 蛾眉（庄姜）: 5条
# 五马渡江: 5条
# 隐墙东（王君公，逢萌）: 5条
# 抢榆枋: 5条
# 切泥: 5条
# 飞琼（西王母，许飞琼）: 5条
# 武库（杜预）: 5条
# 中散琴（嵇康）: 5条
# 琴瑟: 5条
# 家丘（孔子）: 5条
# 青云器（阮咸，颜延年）: 5条
# 琼玖: 5条
# 池中物（周瑜，刘备，周瑜，孙权）: 5条
# 椒花颂（陈氏）: 5条
# 平衡数据:   0%|          | 0/1013 [00:00<?, ?it/s]
# 平衡数据: 100%|██████████| 1013/1013 [00:02<00:00, 497.98it/s]
# 平衡后的典故分布:
# 桃源（陶潜）: 170条
# 阳台（宋玉，楚襄王，瑶姬）: 169条
# 吹箫（弄玉，秦穆公，萧史）: 130条
# 桂枝（郤诜）: 127条
# 白雪（宋玉）: 121条
# 蓬莱: 120条
# 紫芝（刘邦，夏黄公，东园公，甪里先生，绮里季，四皓）: 103条
# 谢朓: 91条
# 陶潜: 88条
# 沧浪（屈原）: 88条
# 鲈鱼（张翰）: 78条
# 三径（求仲，羊仲，蒋诩）: 77条
# 卞和: 76条
# 令威（丁令威）: 75条
# 双剑（干将，张华，莫邪，雷焕）: 69条
# 磻溪（吕尚，周文王）: 68条
# 乘兴（戴逵，王徽之）: 68条
# 骢马（桓典）: 68条
# 五马: 64条
# 大鹏（庄子）: 64条
# 相如（司马相如）: 63条
# 采薇（伯夷，叔齐）: 63条
# 箕颍（尧，许由，巢父）: 20条
# 横汾（刘彻）: 20条
# 飞燕（赵飞燕）: 20条
# 永和（王羲之）: 19条
# 右军鹅（王羲之）: 19条
# 长门: 19条
# 王母桃（东方朔，汉武帝）: 19条
# 长缨（终军）: 19条
# 文翁: 19条
# 含香: 19条
# 悬剑（季札，徐君）: 19条
# 专城: 19条
# 东篱（陶潜）: 19条
# 鹊南飞（曹操）: 19条
# 苍生望（谢安）: 19条
# 南冠（钟仪）: 19条
# 鲍参军（鲍照）: 19条
# 管鲍（管仲，鲍叔牙）: 19条
# 散樗（惠施，庄子）: 19条
# 怀橘（潘岳，陆绩）: 19条
# 报恩珠（曹植）: 19条
# 少微星: 18条
# 扬雄宅（扬雄）: 18条
# 第三声: 18条
# 豹隐（陶答子，陶荅子妻）: 18条
# 夔（伊尹，夔，龙）: 18条
# 云台（邓禹）: 18条
# 酂侯（刘邦，萧何）: 18条
# 未封侯（李广）: 18条
# 弹冠（王吉，贡禹）: 18条
# 子云（扬雄）: 18条
# 雁行: 18条
# 寒灰（韩安国）: 18条
# 罗敷: 18条
# 星郎: 18条
# 柱史（张苍）: 18条
# 章台（张敞）: 18条
# 子虚: 18条
# 庞公: 18条
# 尚平（向长）: 18条
# 易水寒（聂政，荆轲，燕丹）: 18条
# 定远（班超）: 18条
# 濠梁（惠施，庄子）: 17条
# 一叶: 17条
# 麻姑: 17条
# 漉酒（陶潜）: 17条
# 西方社（慧远，宗炳）: 17条
# 画眉（张敞）: 17条
# 蓬山: 17条
# 宣室: 17条
# 棣萼: 17条
# 借寇（寇恂）: 17条
# 解网（汤）: 17条
# 无全牛（庖丁）: 17条
# 还珠（孟尝）: 17条
# 雀罗（翟公）: 17条
# 金掌（汉武帝）: 17条
# 登坛（刘邦，萧何，韩信）: 17条
# 池塘生春草（谢惠连，谢灵运）: 17条
# 中圣（徐邈）: 17条
# 葛洪（葛洪，葛玄）: 17条
# 当垆（卓文君，司马相如）: 17条
# 白社: 16条
# 连城（秦昭王，蔺相如）: 16条
# 瑶台: 16条
# 卧袁安（袁安）: 16条
# 烂柯（王质）: 16条
# 知音: 16条
# 吊屈（贾谊，屈原）: 16条
# 泛梗（苏秦）: 16条
# 龙竹（费长房）: 16条
# 著鞭（祖逖）: 16条
# 披云（乐广，卫瓘）: 16条
# 依刘（王粲，刘表）: 16条
# 洪炉: 16条
# 精卫: 16条
# 祢衡: 16条
# 玉山颓（嵇康）: 16条
# 黄绶: 16条
# 客星（严光）: 16条
# 独醒（屈原）: 16条
# 麋鹿群（伯夷）: 16条
# 梁园（刘武）: 16条
# 临池（张芝）: 16条
# 云中鸡犬（刘安）: 15条
# 五丁: 15条
# 骏骨（燕昭王，郭隗）: 15条
# 焦尾（蔡邕）: 15条
# 击壤（尧，舜）: 15条
# 石渠: 15条
# 金马客（东方朔）: 15条
# 青蝇: 15条
# 移文（周颙，孔稚圭）: 15条
# 安期（安期生）: 15条
# 石桥（秦始皇）: 15条
# 分阃: 15条
# 倚天剑: 15条
# 侯嬴: 15条
# 趋庭（孔子，孔鲤，陈亢）: 15条
# 木奴（孙休，李衡）: 15条
# 白眉（马良）: 15条
# 陵谷: 15条
# 祢衡挝（孔融，曹操，祢衡）: 15条
# 玉京: 15条
# 甑生尘（范冉）: 15条
# 渥洼种: 15条
# 金诺（季布，曹丘生）: 15条
# 风驭（列禦寇）: 15条
# 梁苑客（刘武，司马相如，邹阳，枚乘）: 15条
# 文姬（蔡琰，蔡邕，曹操）: 15条
# 金兰: 15条
# 桃叶（桃叶，王子敬，王献之）: 15条
# 缩地（费长房）: 15条
# 骅骝: 15条
# 石崇: 15条
# 刀头（任立政，李陵）: 15条
# 劫灰（刘彻）: 15条
# 日车（羲和）: 15条
# 过隙: 15条
# 月桂: 15条
# 大隐: 15条
# 蟾: 15条
# 六印（苏秦）: 15条
# 倒屣（王粲，蔡邕）: 15条
# 书空（殷浩）: 15条
# 遏云（秦青，薛谭）: 15条
# 傅野（傅说，武丁）: 15条
# 阮籍: 15条
# 长安日（司马昭）: 15条
# 刘伶（刘伶）: 15条
# 萧曹: 15条
# 北海尊（孔融）: 15条
# 谏猎（扬雄）: 15条
# 萱草: 15条
# 梁尘（虞公）: 15条
# 韩寿（贾充，贾午，韩寿）: 15条
# 贾生泪（贾谊）: 15条
# 逐鹿（蒯通）: 15条
# 鹤氅: 15条
# 千日醉（刘玄石）: 15条
# 盐车（汗明，伯乐）: 15条
# 曳裾（邹阳）: 15条
# 买赋（刘彻，司马相如，陈皇后）: 15条
# 陶令醉（陶潜）: 15条
# 河源（张骞）: 15条
# 为霖（傅说，殷高宗）: 15条
# 天骄: 15条
# 偷桃（东方朔）: 15条
# 飞锡: 15条
# 公干（刘桢）: 15条
# 鸡黍（张劭，范式）: 15条
# 凤诏（石虎）: 15条
# 褰帷: 15条
# 方朔（东方朔）: 15条
# 西园（曹丕）: 15条
# 羊公（羊祜）: 15条
# 斩楼兰（刘彻）: 15条
# 暗投（邹阳）: 15条
# 右军（王羲之）: 15条
# 梁甫（诸葛亮）: 15条
# 隐侯（沈约，鲍照）: 15条
# 箫韶: 15条
# 明妃（王昭君）: 15条
# 南浦（江淹）: 15条
# 黄绢（曹操，杨修，杨脩，曹娥，曹盱）: 15条
# 八骏（周穆王，西王母）: 15条
# 骑省（潘岳）: 15条
# 鼓瑟（女英，娥皇，舜）: 15条
# 邓林（夸父）: 15条
# 鹦鹉赋: 15条
# 衔环（杨宝）: 15条
# 蒲轮（刘彻）: 15条
# 闲居赋（潘岳）: 15条
# 黄屋: 15条
# 子房（张良）: 15条
# 大王风（宋玉，楚王）: 15条
# 木雁（庄子）: 15条
# 下帷（董仲舒）: 15条
# 李将军（李广，卫青）: 15条
# 弦惊（魏加）: 15条
# 楚材: 15条
# 齐竽（南郭先生）: 15条
# 文园: 15条
# 前席（贾谊）: 15条
# 拥鼻（谢安）: 15条
# 三顾（刘备，诸葛亮）: 15条
# 天马（刘彻）: 15条
# 从军乐（王粲）: 15条
# 贪泉（吴隐之）: 15条
# 伯乐: 15条
# 补天（女娲）: 15条
# 倚玉（夏侯玄，曹睿，毛曾）: 15条
# 抽簪: 15条
# 冲天（楚庄王，淳于髡，齐威王）: 15条
# 方寸: 15条
# 东床（王羲之）: 15条
# 伯道无儿（邓攸）: 15条
# 宴镐（周武王）: 15条
# 桑榆: 15条
# 瓮间卧（毕卓）: 15条
# 五车（惠施，庄子）: 15条
# 三独（宣秉）: 15条
# 直如弦: 15条
# 此君（王徽之）: 15条
# 潜夫（王符）: 15条
# 纵横: 15条
# 下车（武王）: 15条
# 日边（司马昭）: 15条
# 铁冠: 15条
# 佩刀（吕虔，王祥，王览）: 15条
# 黄霸: 15条
# 伍员涛（伍员，文种）: 15条
# 萧寺（萧子云，萧衍）: 15条
# 栖梧: 15条
# 张骞: 15条
# 三岁字: 15条
# 孟母邻（孟子，孟母）: 15条
# 钓鳌: 15条
# 陆机: 15条
# 埋轮（侯文，张纲）: 15条
# 月窟: 15条
# 买山（支遁，深公，巢父，许由）: 15条
# 归去来（陶潜）: 15条
# 颍川政（黄霸）: 15条
# 扫门（魏勃）: 15条
# 嵇康懒（山涛，嵇康）: 15条
# 佳气（刘秀，苏伯阿）: 15条
# 漂母（韩信，漂母）: 15条
# 金微: 15条
# 元瑜（阮瑀）: 15条
# 傲吏: 15条
# 三千客（田文，魏无忌，黄歇）: 15条
# 山涛: 15条
# 薜荔衣: 15条
# 误曲（周瑜）: 15条
# 九门: 15条
# 张仪: 15条
# 黍离: 15条
# 抱瓮（庄子）: 15条
# 毛遂（毛遂，赵胜）: 15条
# 灌园: 15条
# 尝胆（勾践）: 15条
# 魂招（屈原，宋玉）: 15条
# 牧马（黄帝，大隗）: 15条
# 伶伦（伶伦，黄帝）: 15条
# 金蟾: 15条
# 龙媒: 15条
# 解佩（郑交甫）: 15条
# 狗盗（田文）: 15条
# 荀令香（荀彧）: 15条
# 留侯: 15条
# 朝宗: 15条
# 小阮（阮咸，阮籍）: 15条
# 塞上翁（塞翁）: 15条
# 上蔡（李斯，赵高）: 15条
# 长者车（陈平）: 15条
# 玄圃（周穆王）: 15条
# 掷地（孙绰）: 15条
# 淮阳卧（汲黯）: 15条
# 傅岩（傅说）: 15条
# 衔芦: 15条
# 斩蛇（刘邦）: 15条
# 席上珍（孔子）: 15条
# 流霞: 15条
# 坑降（白起）: 15条
# 七贵: 15条
# 鲁阳戈（鲁阳公）: 15条
# 击筑（高渐离，荆轲，狗屠）: 15条
# 钧天（赵简子）: 15条
# 邹枚: 15条
# 雕龙: 15条
# 一顾（伯乐，淳于髡，苏代）: 15条
# 三车: 15条
# 种玉（杨伯雍）: 15条
# 芸阁: 15条
# 河梁: 15条
# 班姬（班婕妤）: 15条
# 八龙（荀淑）: 15条
# 鹊喜: 15条
# 肘后方（葛洪）: 15条
# 曹刘（刘桢，曹植）: 15条
# 扶桑: 15条
# 禹凿（夏禹）: 15条
# 庄椿（庄子）: 15条
# 尧蓂（尧）: 15条
# 煮白石: 15条
# 鲁恭（刘馀）: 15条
# 迷下蔡（宋玉）: 15条
# 韩康: 15条
# 突不黔（墨子，孔子）: 15条
# 郗超（王珣，郗超）: 15条
# 雕虫: 15条
# 鹑服: 15条
# 负郭（苏秦）: 15条
# 鸣岐: 15条
# 何郎（何晏，曹睿）: 15条
# 薏苡谤（马援）: 15条
# 铜柱（马援）: 15条
# 镊白（左思，齐高帝）: 15条
# 诸生（叔孙通）: 15条
# 潘兴（潘岳）: 15条
# 卧辙（侯霸，秦彭）: 15条
# 负鼎（伊尹）: 15条
# 平子赋（张衡）: 15条
# 题凤（吕安，嵇喜，嵇康）: 15条
# 贰师: 15条
# 蜗舍: 15条
# 式微: 15条
# 公主嫁乌孙（刘建，刘细君，乌孙昆莫）: 15条
# 青衿: 15条
# 旰食（伍奢）: 15条
# 梅妆（寿阳公主）: 15条
# 六龙: 15条
# 柳恽: 15条
# 起予（卜商，孔子）: 15条
# 灵和柳（张绪）: 15条
# 履声（郑崇）: 15条
# 庾公（庾亮）: 15条
# 玄度: 15条
# 士龙（荀隐，陆云）: 15条
# 铃阁: 15条
# 埙篪: 15条
# 刘桢病（刘桢）: 15条
# 周郎: 15条
# 荐祢（孔融，邹阳，祢衡）: 15条
# 一戎: 15条
# 曾参: 15条
# 许由: 15条
# 前筹（张良）: 15条
# 竹马: 15条
# 青囊: 15条
# 洗兵: 15条
# 鹿鸣: 15条
# 王陵戆（刘邦，王陵）: 15条
# 少君: 15条
# 绕朝策（士会，绕朝）: 15条
# 生公: 15条
# 绝交书（山涛，嵇康）: 15条
# 逐客（李斯）: 15条
# 黔娄: 15条
# 守株: 15条
# 考槃: 15条
# 千金笑: 15条
# 谢家（谢灵运）: 15条
# 天鸡: 15条
# 鲛室: 15条
# 杞国忧: 15条
# 投阁（扬雄，王莽）: 15条
# 温树: 15条
# 酷似（何无忌，刘牢之，刘裕）: 15条
# 五千言: 15条
# 嫫母（嫫母，西施）: 15条
# 庄周: 15条
# 琼瑶: 15条
# 向隅: 15条
# 琪树: 15条
# 望梅（曹操）: 15条
# 藁砧: 15条
# 倾盖（邹阳）: 15条
# 腐草: 15条
# 巴字: 15条
# 从龙: 15条
# 北堂: 15条
# 郢匠（惠施，庄子）: 15条
# 铄金: 15条
# 埋玉（庾亮）: 15条
# 存老马（管仲）: 15条
# 大树（溤异）: 15条
# 戴颙: 15条
# 担簦（虞卿）: 15条
# 不为家（霍去病）: 15条
# 死灰（南郭子）: 15条
# 白马小儿（侯景）: 15条
# 负薪（披裘公）: 15条
# 非熊（周文王）: 15条
# 青女: 15条
# 知非（蘧瑗）: 15条
# 一苇: 15条
# 山屐（谢灵运）: 15条
# 高阳酒徒（郦生）: 15条
# 股肱: 15条
# 谢将军（袁宏，谢尚）: 15条
# 白猿: 15条
# 韩娥（薛谭，韩娥）: 15条
# 五裤歌（廉范）: 15条
# 置醴（楚元王，白生，穆生，陈申公）: 15条
# 倚马（桓温，袁虎）: 15条
# 子玉（崔瑗）: 15条
# 骊歌（王式）: 15条
# 秦鸡（陈宝）: 15条
# 葭灰: 15条
# 桂玉（苏秦）: 15条
# 关令（尹喜）: 15条
# 白杨悲: 15条
# 张公子: 15条
# 于陵子（陈仲子）: 15条
# 爱吾庐（陶潜）: 15条
# 征南: 15条
# 击唾壶（王敦）: 15条
# 戴逵（戴逵）: 15条
# 三害（周处）: 15条
# 葵藿（曹植）: 15条
# 武库火（刘邦）: 15条
# 千里莼（王济，陆机）: 15条
# 孔丘（孔子）: 15条
# 昼锦游（张既）: 15条
# 及瓜（连称，齐侯）: 15条
# 嵇阮: 15条
# 黄竹（周穆王）: 15条
# 绝编（孔子）: 15条
# 斥鴳: 15条
# 龙韬: 15条
# 一丸（王元，隗嚣）: 15条
# 褒女（周幽王，褒姒）: 15条
# 投杼（曾参）: 15条
# 胶漆: 15条
# 缝掖: 15条
# 指鹿（赵高）: 15条
# 三窟（田文，冯谖）: 15条
# 凤雏: 15条
# 阊阖（屈原）: 15条
# 系名王（贾谊）: 15条
# 加餐: 15条
# 凤求皇（卓文君，司马相如）: 15条
# 逸少: 15条
# 孟尝（田文）: 15条
# 蚩尤: 15条
# 覆水难收: 15条
# 分泾: 15条
# 灵台（第五颉）: 15条
# 苏门啸（阮籍，孙登）: 15条
# 汲黯直（汲黯）: 15条
# 高价: 15条
# 梦鸟（罗含）: 15条
# 诛茅（屈原）: 15条
# 拔山（项羽，虞姬）: 15条
# 祝融: 15条
# 伍员死（伍员）: 15条
# 五云车: 15条
# 搀抢: 15条
# 紫府: 15条
# 宗雷: 15条
# 祖龙（秦始皇）: 15条
# 阿侯: 15条
# 彭泽田（陶潜）: 15条
# 五羖（晋献公，百里傒）: 15条
# 掩鼻（郑袖）: 15条
# 阿娇: 15条
# 坐啸: 15条
# 潘郎泪（潘岳）: 15条
# 左思: 15条
# 玉壶冰（鲍照）: 15条
# 柱史（老子）: 15条
# 轩冕: 15条
# 玄成: 15条
# 板舆（潘岳）: 15条
# 辟疆园: 15条
# 即墨牛（田单）: 15条
# 应徐: 15条
# 颍阳（尧，许由）: 15条
# 饮冰: 15条
# 白登围（刘邦）: 15条
# 烛龙: 15条
# 阳侯: 15条
# 一麾（阮咸，阮咸，颜延之）: 15条
# 鱼目: 15条
# 养鸡（祝鸡翁）: 15条
# 银钩: 15条
# 游梁: 15条
# 商陵（南陵牧子）: 15条
# 班荆: 15条
# 太常妻（周泽）: 15条
# 等浮云（孔子）: 15条
# 吐凤才（扬雄）: 15条
# 鹄箭: 15条
# 枳棘鸾（仇览，仇香，王涣）: 15条
# 白马将: 15条
# 郑卫: 15条
# 周召: 15条
# 酒中蛇（杜宣，乐广）: 15条
# 张长公（张挚）: 15条
# 麻衣: 15条
# 心匪石: 15条
# 帝乡（庄子）: 15条
# 鸡群（王戎）: 15条
# 一掷（刘毅）: 15条
# 白笔: 15条
# 騕袅: 15条
# 蕊珠: 15条
# 无何乡: 15条
# 观风: 15条
# 生入关（班超）: 15条
# 杨仆移关（刘彻，杨仆）: 15条
# 梁王（刘武）: 15条
# 姜被（姜肱）: 15条
# 谢临川（谢灵运）: 15条
# 弓剑: 15条
# 骑羊（葛由）: 15条
# 五马渡江: 15条
# 隐墙东（王君公，逢萌）: 15条
# 抢榆枋: 15条
# 切泥: 15条
# 飞琼（西王母，许飞琼）: 15条
# 武库（杜预）: 15条
# 中散琴（嵇康）: 15条
# 琴瑟: 15条
# 家丘（孔子）: 15条
# 青云器（阮咸，颜延年）: 15条
# 琼玖: 15条
# 池中物（周瑜，刘备，周瑜，孙权）: 15条
# 椒花颂（陈氏）: 15条
#
# 平衡后统计:
# 平均样本数: 19.83
# 标准差: 14.13
# 原始数据集大小: 14969
# 平衡后数据集大小: 20092
#
# 平衡后的数据集已保存至: 3_2_balanced_data.csv

# %% [markdown]
# 4、训练集测试集划分

# %%
from sklearn.model_selection import train_test_split
import os

# %%
def split_dataset(input_file,dataset_name, train_ratio=0.8, random_state=42):
    """
    将数据集分割为训练集和测试集
    
    Args:
        input_file: 输入文件路径 (final_data.csv)
        train_ratio: 训练集比例，默认0.8
        random_state: 随机种子，默认42
    """
    print(f"开始读取数据文件: {input_file}")
    
    # 读取CSV文件
    df = pd.read_csv(input_file, sep='\t')
    print(f"总数据量: {len(df)}")
    
    # 获取包含典故的样本
    df_with_allusions = df[df['variation_number'] != '0']
    
    print(f"包含典故的样本数: {len(df_with_allusions)}")
    
    # 分别对包含典故和不包含典故的样本进行分割
    train_df, test_df = train_test_split(
        df_with_allusions,
        train_size=train_ratio,
        random_state=random_state,
        shuffle=True
    )
    
    # 打乱数据顺序
    train_df = train_df.sample(frac=1, random_state=random_state).reset_index(drop=True)
    test_df = test_df.sample(frac=1, random_state=random_state).reset_index(drop=True)
    
    # 保存文件
    train_file = '4_train.csv'
    test_file = '4_test.csv'
    
    train_df.to_csv(train_file, sep='\t', index=False)
    test_df.to_csv(test_file, sep='\t', index=False)
    
    print("\n数据集分割完成:")
    print(f"训练集大小: {len(train_df)}")
    print(f"测试集大小: {len(test_df)}")
    print(f"训练集保存至: {train_file}")
    print(f"测试集保存至: {test_file}")
    
    # 打印包含典故的样本统计
    print("\n包含典故的样本统计:")
    print(f"训练集中包含典故的样本数: {len(train_df[train_df['variation_number'] != '0'])}")
    print(f"测试集中包含典故的样本数: {len(test_df[test_df['variation_number'] != '0'])}")

if __name__ == "__main__":
        input_file = "3_1_merged_data.csv"
        split_dataset(input_file,'position')
        
        input_file = "3_2_balanced_data.csv"
        split_dataset(input_file,'type')
# Out:
# 开始读取数据文件: 3_1_merged_data.csv
# 总数据量: 13390
# 包含典故的样本数: 13390
#
# 数据集分割完成:
# 训练集大小: 10712
# 测试集大小: 2678
# 训练集保存至: 4_train.csv
# 测试集保存至: 4_test.csv
#
# 包含典故的样本统计:
# 训练集中包含典故的样本数: 10712
# 测试集中包含典故的样本数: 2678
# 开始读取数据文件: 3_2_balanced_data.csv
# 总数据量: 20092
# 包含典故的样本数: 20092
#
# 数据集分割完成:
# 训练集大小: 16073
# 测试集大小: 4019
# 训练集保存至: 4_train.csv
# 测试集保存至: 4_test.csv
#
# 包含典故的样本统计:
# 训练集中包含典故的样本数: 16073
# 测试集中包含典故的样本数: 4019
